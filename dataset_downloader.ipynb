# %%
import sys
# !{sys.executable} -m pip install gdown
import gdown
# Out:
# ...
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# ...
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [gdown]
# ...

# %%
url_TopOGNet = "https://drive.google.com/file/d/1L7NWkhkkaKP6q74o1jBO-2SxuAkeDBLn/view"
url_RealPC =   "https://drive.google.com/file/d/1decE9LodqeZP1C4zIxgqXBgvDZWD87j2/view"
url_RealPC_ShapeNet = "https://drive.google.com/file/d/1_UFIqR-HrbOra6xL0kiM26TV4_YySbgD/view"
output_T = "TopOGNet.zip"
output_R = "RealPC.zip"
output_R_ShapeNet = "RealPC_ShapeNet.zip"

# %%
gdown.download(url_RealPC_ShapeNet, output_R_ShapeNet, quiet=False)
#gdown.download(url_RealPC, output_R, quiet=False, fuzzy=True)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1_UFIqR-HrbOra6xL0kiM26TV4_YySbgD
# From (redirected): https://drive.google.com/uc?id=1_UFIqR-HrbOra6xL0kiM26TV4_YySbgD&confirm=t&uuid=fa43475e-97b9-48b8-9157-ec69b5695450
# To: /home/tepper/generative-point-cloud-completion/RealPC_ShapeNet.zip
# 100%|██████████| 808M/808M [00:33<00:00, 24.0MB/s]
# 'RealPC_ShapeNet.zip'
